# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
jan = pd.read_csv('csv/jan.csv')
del jan['Unnamed: 0']
jan.head()
# Out:
#   line  day_of_week  hour  day  month  count
# 0    4            2    17   20      1      3
# 1    5            4    17   22      1      2
# 2    G            4     5   15      1      1
# 3    L            1    22   26      1      2
# 4    L            2    13    6      1      1

# %%
lines= (jan.groupby('line').sum()).sort(columns=['count'],ascending =False).index
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':

# %%
#lines = list(set(jan.line.values))

# %%
dow_jan = jan.groupby(['line','day_of_week']).sum()

# %%
import matplotlib._color_data as mcd

# %%
dow_jan.iloc[dow_jan.index.get_level_values('line') == i].index.labels[1]
# Out:
# FrozenNDArray([0, 1, 2, 3, 4, 5, 6], dtype='int8')

# %%
dow_jan
# Out:
#                   hour   day  month  count
# line day_of_week
# 1    0            1101  1377     94    758
#      1            1094  1452     93    918
#      2            1095  1524     93    896
#      3            1101  1659     95    957
#      4            1380  1800    120   1278
#      5            1217  1713    111   1372
#      6            1352  1872    113   1159
# 2    0             909  1051     72    167
#      1             980  1278     82    200
#      2             973  1281     77    204
#      3            1008  1421     81    226
#      4            1272  1712    109    310
#      5            1134  1571    103    308
#      6            1162  1562     96    271
# 3    0             915  1076     73    168
#      1             980  1278     82    201
#      2             972  1261     76    203
#      3            1013  1400     80    227
#      4            1272  1712    109    309
#      5            1115  1553    101    303
# ...

# %%
col = sorted(mcd.CSS4_COLORS.keys())[10::2]
plt.figure(figsize=(10,6))
n=0

for i in lines:
    #if len(dow_jan.iloc[dow_jan.index.get_level_values('line') == i]['count'])!= 7:
    #   continue
    plt.plot(dow_jan.iloc[dow_jan.index.get_level_values('line') == i].index.labels[1],
             dow_jan.iloc[sum_jan.index.get_level_values('line') == i]['count'],
             label=i,c =col[n].upper(),linewidth=2)
    n+=1
plt.xticks(range(7),['Mon','Tue','Wed','Thu','Fri','Sat','Sun'])
plt.xlim(0,6)
plt.ylabel('yellow cab trips',fontsize=15)
plt.xlabel('day of week',fontsize=15)
plt.title('How many people prefer yellow cab than subway?\n(by day of week,Jan2016)',fontsize=20)
    
plt.legend(bbox_to_anchor=(1.05, 1),loc=2)

# %% [markdown]
# #### Caption: Legend sort by total trip in Jan

# %%
hour_jan = jan.groupby(['line','hour']).sum()

# %%
hour_jan.iloc[hour_jan.index.get_level_values('line') == '1']['count']
# Out:
# line  hour
# 1     0       241
#       1       195
#       2       134
#       3        86
#       4        81
#       5        96
#       6       177
#       7       190
#       8       264
#       9       338
#       10      336
#       11      396
#       12      431
#       13      363
#       14      449
#       15      400
#       16      381
#       17      410
#       18      502
#       19      490
#       20      376
#       21      358
#       22      356
#       23      288
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
n=0

for i in lines:
    plt.plot(hour_jan.iloc[hour_jan.index.get_level_values('line') == i].index.labels[1],
             hour_jan.iloc[hour_jan.index.get_level_values('line') == i]['count'],
             label = i, c =col[n].upper(),linewidth=2)
    n+=1
plt.xlim(0,23)
plt.ylabel('yellow cab trips',fontsize=15)
plt.xlabel('hour',fontsize=15)
plt.title('How many people prefer yellow cab than subway?\n(by hour,Jan2016)',fontsize=20)
plt.legend(bbox_to_anchor=(1.05, 1),loc=2)

# %% [markdown]
# #### Caption: Legend sort by total trip in Jan
